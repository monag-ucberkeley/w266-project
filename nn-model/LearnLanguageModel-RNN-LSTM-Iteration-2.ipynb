# %%
import json, os, re, shutil, sys, time, csv
import collections, itertools

# NLTK for NLP utils and corpora
import nltk

# NumPy and TensorFlow
import numpy as np
import tensorflow as tf
assert(tf.__version__.startswith("1."))

# utils.pretty_print_matrix uses Pandas. Configure float format here.
import pandas as pd
pd.set_option('float_format', lambda f: "{0:.04f}".format(f))

# Helper libraries
from shared_lib import utils, vocabulary, rnnlm

# %%
canonicalized_words = []
indir = '../preprocess/'
books = []
for root, dirs, filenames in os.walk(indir):
    for filename in filenames:
        if filename.startswith('canonicalized_words_'):
            with open(indir+filename, 'r') as f:
                for line in f.readlines():
                    canonicalized_words.append(line.rstrip())
num_words = len(canonicalized_words)
print num_words
print canonicalized_words[0:10]
print canonicalized_words[num_words-10:num_words]
# Out:
# 163757603
# ['lincoln', "'s", 'first', 'inaugural', 'address', 'march', 'DG', ',', 'DGDGDGDG', 'fellow']
# ['wings', 'speeded', 'like', 'thought', 'upon', 'the', 'light', 'of', 'heaven', '.']

# %%
## Generate the vocabulary
V = 10000
vocab = vocabulary.Vocabulary((w for w in words), size=V)

# %%
sents = []
indir = '../preprocess/'
books = []
for root, dirs, filenames in os.walk(indir):
    for filename in filenames:
        if filename.startswith('parsed_sents_'):
            with open(indir+filename, 'r') as f:
                for line in f.readlines():
                    sents.append(line.rstrip())
num_sents = len(sents)
print num_sents
print sents[num_sents-10:num_sents]
# Out:
# 9494082
# ['<s> FOR SALE WHEREVER BOOKS ARE SOLD . </s>', '<s> J. S. OGILVIE PUBLISHING COMPANY 57 Rose Street , New York OGILVIE \'S POPULAR COPYRIGHT LINE THE PEER AND THE WOMAN BY E. PHILLIPS OPPENHEIM AUTHOR OF " A MONK OF CRUTA , " " THE MISSIONER , " ETC . </s>', '<s> _ One of the Most Popular Authors of the present day . </s>', '<s> _ * * * * * A story of romance , mystery , and adventure , in which , as in many mystery stories , there is the adventuress , with whom , for some reason , the peer , notwithstanding his breeding and social position , becomes entangled , until he is mysteriously put out of the way . </s>', '<s> From this point on complication and adventure succeed each other in rapid succession , holding the reader in rapt fascination until the end of the story is reached , where the plots of love and mysterious disappearances are surprisingly unfolded . </s>', "<s> This story has been written in Mr. Oppenheim 's most entertaining and interesting style , and will be appreciated by all lovers of the class of fiction which has made him famous . </s>", '<s> _ A Wonderful Story of Mystery . </s>', '<s> _ * * * * * Bound in cloth , handsomely stamped in colors . </s>', '<s> * * * * * SENT BY MAIL , POSTAGE PAID , FOR 75 CENTS . </s>', '<s> You can buy this at any bookstore or direct from us . </s>']

# %%
corpus = np.array(list(sents), dtype=object)
print len(corpus)
# Out:
# 9494082

# %%
def preprocess_sentences(sentences, vocab):
    """Preprocess sentences by canonicalizing and mapping to ids.

    Args:
      sentences ( list(list(string)) ): input sentences
      vocab: Vocabulary object, already initialized

    Returns:
      ids ( array(int) ): flattened array of sentences, including boundary <s>
      tokens.
    """
    # Add sentence boundaries, canonicalize, and handle unknowns
    words = (s for s in sentences)
    words = [utils.canonicalize_word(w, wordset=vocab.word_to_id)
             for w in words]
    return np.array(vocab.words_to_ids(words))

split=0.8 
shuffle=True

"""Get train and test sentences.

Args:
  corpus: sentences parsed from the Gutenberg Contemporary Authors corpus
  split (double): fraction to use as training set
  shuffle (int or bool): seed for shuffle of input data, or False to just
  take the training data as the first xx% contiguously.
  train_sentences, test_sentences ( list(list(string)) ): the train and test splits
"""

sentences = np.array(corpus, dtype=object)
fmt = (len(sentences), sum(map(len, sentences)))
print "Loaded %d sentences (%g tokens)" % fmt

if shuffle:
    rng = np.random.RandomState(shuffle)
    rng.shuffle(sentences)  # in-place
train_frac = 0.8
split_idx = int(train_frac * len(sentences))
train_sentences = sentences[:split_idx]
test_sentences = sentences[split_idx:]

fmt = (len(train_sentences), sum(map(len, train_sentences)))
print "Training set: %d sentences (%d tokens)" % fmt
fmt = (len(test_sentences), sum(map(len, test_sentences)))
print "Test set: %d sentences (%d tokens)" % fmt

## convert words to ids based on the vocab wordset created above
train_ids = preprocess_sentences(train_sentences, vocab)
test_ids = preprocess_sentences(test_sentences, vocab)
# Out:
# Loaded 9494082 sentences (1.10435e+09 tokens)
# Training set: 7595265 sentences (883446998 tokens)
# Test set: 1898817 sentences (220906362 tokens)

# %%
def run_epoch(lm, session, batch_iterator,
              train=False, verbose=False,
              tick_s=10, learning_rate=0.1):
    start_time = time.time()
    tick_time = start_time  # for showing status
    total_cost = 0.0  # total cost, summed over all words
    total_batches = 0
    total_words = 0

    if train:
        train_op = lm.train_step_
        use_dropout = False
        loss = lm.train_loss_
    else:
        train_op = tf.no_op()
        use_dropout = False  # no dropout at test time
        loss = lm.loss_  # true loss, if train_loss is an approximation

    for i, (w, y) in enumerate(batch_iterator):
        cost = 0.0
        # At first batch in epoch, get a clean intitial state.
        if i == 0:
            h = session.run(lm.initial_h_, {lm.input_w_: w})

        #### YOUR CODE HERE ####
        feed_dict = {lm.input_w_: w, lm.target_y_: y, lm.initial_h_: h}
        ## print "Calling computational graph"
        cost, train_op_ = session.run([loss, train_op], feed_dict)
        #### END(YOUR CODE) ####
        total_cost += cost
        total_batches = i + 1
        total_words += w.size  # w.size = batch_size * max_time
        

        ##
        # Print average loss-so-far for epoch
        # If using train_loss_, this may be an underestimate.
        if verbose and (time.time() - tick_time >= tick_s):
            avg_cost = total_cost / total_batches
            avg_wps = total_words / (time.time() - start_time)
            print "[batch %d]: seen %d words at %d wps, loss = %.3f" % (
                i, total_words, avg_wps, avg_cost)
            tick_time = time.time()  # reset time ticker

    return total_cost / total_batches

# %%
def score_dataset(lm, session, ids, name="Data"):
    # For scoring, we can use larger batches to speed things up.
    bi = utils.batch_generator(ids, batch_size=100, max_time=100)
    cost = run_epoch(lm, session, bi, 
                     learning_rate=1.0, train=False, 
                     verbose=False, tick_s=3600)
    print "%s: avg. loss: %.03f  (perplexity: %.02f)" % (name, cost, np.exp(cost))

# %%
max_time = 50
batch_size = 20
learning_rate = 0.5
num_epochs = 5

# Model parameters
model_params = dict(V=vocab.size, 
                    H=100, 
                    softmax_ns=200,
                    num_layers=3)

TF_SAVEDIR = "tf_saved"
checkpoint_filename = os.path.join(TF_SAVEDIR, "rnnlm")
trained_filename = os.path.join(TF_SAVEDIR, "rnnlm_trained")

# %%
# Will print status every this many seconds
print_interval = 5

# Clear old log directory
shutil.rmtree("tf_summaries", ignore_errors=True)

lm = rnnlm.RNNLM(**model_params)
lm.BuildCoreGraph()
lm.BuildTrainGraph()

# Explicitly add global initializer and variable saver to LM graph
with lm.graph.as_default():
    initializer = tf.global_variables_initializer()
    saver = tf.train.Saver()
    
# Clear old log directory
shutil.rmtree(TF_SAVEDIR, ignore_errors=True)
if not os.path.isdir(TF_SAVEDIR):
    os.makedirs(TF_SAVEDIR)

with tf.Session(graph=lm.graph) as session:
    # Seed RNG for repeatability
    tf.set_random_seed(42)

    session.run(initializer)

    for epoch in xrange(1,num_epochs+1):
        t0_epoch = time.time()
        bi = utils.batch_generator(train_ids, batch_size, max_time)
        print "[epoch %d] Starting epoch %d" % (epoch, epoch)
        #### YOUR CODE HERE ####
        # Run a training epoch.
        
        run_epoch(lm, session, bi,
              train=True, verbose=True,
              tick_s=10, learning_rate=0.1)
        
        #### END(YOUR CODE) ####
        print "[epoch %d] Completed in %s" % (epoch, utils.pretty_timedelta(since=t0_epoch))
    
        # Save a checkpoint
        saver.save(session, checkpoint_filename, global_step=epoch)
    ##
    # score_dataset will run a forward pass over the entire dataset
    # and report perplexity scores. This can be slow (around 1/2 to 
    # 1/4 as long as a full epoch), so you may want to comment it out
    # to speed up training on a slow machine. Be sure to run it at the 
    # end to evaluate your score.
    print ("[epoch %d]" % epoch),
    score_dataset(lm, session, train_ids, name="Train set")
    print ("[epoch %d]" % epoch),
    score_dataset(lm, session, test_ids, name="Test set")
    print ""
    # Save final model
    saver.save(session, trained_filename)
# Out:
# [epoch 1] Starting epoch 1
# [batch 39]: seen 40000 words at 3930 wps, loss = 0.733
# [batch 79]: seen 80000 words at 3942 wps, loss = 0.404
# [batch 119]: seen 120000 words at 3930 wps, loss = 0.283
# [batch 159]: seen 160000 words at 3947 wps, loss = 0.217
# [batch 199]: seen 200000 words at 3945 wps, loss = 0.175
# [batch 239]: seen 240000 words at 3953 wps, loss = 0.146
# [batch 279]: seen 280000 words at 3952 wps, loss = 0.126
# [batch 320]: seen 321000 words at 3962 wps, loss = 0.110
# [batch 360]: seen 361000 words at 3963 wps, loss = 0.098
# [batch 401]: seen 402000 words at 3969 wps, loss = 0.088
# [batch 442]: seen 443000 words at 3979 wps, loss = 0.080
# [batch 483]: seen 484000 words at 3982 wps, loss = 0.073
# [batch 524]: seen 525000 words at 3986 wps, loss = 0.068
# [batch 565]: seen 566000 words at 3993 wps, loss = 0.063
# [batch 606]: seen 607000 words at 3999 wps, loss = 0.059
# [batch 647]: seen 648000 words at 3998 wps, loss = 0.055
# [batch 687]: seen 688000 words at 3997 wps, loss = 0.052
# [batch 728]: seen 729000 words at 3998 wps, loss = 0.049
# [batch 768]: seen 769000 words at 3996 wps, loss = 0.046
# [batch 810]: seen 811000 words at 4002 wps, loss = 0.044
# [batch 850]: seen 851000 words at 3999 wps, loss = 0.042
# [batch 891]: seen 892000 words at 4002 wps, loss = 0.040
# [batch 933]: seen 934000 words at 4009 wps, loss = 0.038
# [batch 973]: seen 974000 words at 4006 wps, loss = 0.037
# [batch 1014]: seen 1015000 words at 4007 wps, loss = 0.035
# [batch 1054]: seen 1055000 words at 4007 wps, loss = 0.034
# [batch 1095]: seen 1096000 words at 4010 wps, loss = 0.033
# [batch 1136]: seen 1137000 words at 4012 wps, loss = 0.031
# [batch 1177]: seen 1178000 words at 4014 wps, loss = 0.030
# [batch 1219]: seen 1220000 words at 4018 wps, loss = 0.029
# [batch 1260]: seen 1261000 words at 4017 wps, loss = 0.028
# [batch 1301]: seen 1302000 words at 4019 wps, loss = 0.028
# [batch 1340]: seen 1341000 words at 4014 wps, loss = 0.027
# [batch 1381]: seen 1382000 words at 4016 wps, loss = 0.026
# [batch 1422]: seen 1423000 words at 4018 wps, loss = 0.025
# [batch 1463]: seen 1464000 words at 4019 wps, loss = 0.024
# [batch 1505]: seen 1506000 words at 4024 wps, loss = 0.024
# [batch 1546]: seen 1547000 words at 4024 wps, loss = 0.023
# [batch 1587]: seen 1588000 words at 4025 wps, loss = 0.023
# [batch 1627]: seen 1628000 words at 4023 wps, loss = 0.022
# [batch 1668]: seen 1669000 words at 4025 wps, loss = 0.021
# [batch 1710]: seen 1711000 words at 4027 wps, loss = 0.021
# [batch 1752]: seen 1753000 words at 4030 wps, loss = 0.020
# [batch 1795]: seen 1796000 words at 4036 wps, loss = 0.020
# [batch 1836]: seen 1837000 words at 4035 wps, loss = 0.020
# [batch 1876]: seen 1877000 words at 4034 wps, loss = 0.019
# [batch 1916]: seen 1917000 words at 4033 wps, loss = 0.019
# [batch 1958]: seen 1959000 words at 4035 wps, loss = 0.018
# [batch 1999]: seen 2000000 words at 4036 wps, loss = 0.018
# [batch 2040]: seen 2041000 words at 4036 wps, loss = 0.018
# [batch 2081]: seen 2082000 words at 4037 wps, loss = 0.017
# [batch 2121]: seen 2122000 words at 4035 wps, loss = 0.017
# [batch 2163]: seen 2164000 words at 4036 wps, loss = 0.017
# [batch 2204]: seen 2205000 words at 4037 wps, loss = 0.016
# [batch 2244]: seen 2245000 words at 4036 wps, loss = 0.016
# [batch 2284]: seen 2285000 words at 4034 wps, loss = 0.016
# [batch 2325]: seen 2326000 words at 4034 wps, loss = 0.015
# [batch 2365]: seen 2366000 words at 4032 wps, loss = 0.015
# [batch 2405]: seen 2406000 words at 4032 wps, loss = 0.015
# [batch 2447]: seen 2448000 words at 4034 wps, loss = 0.015
# [batch 2489]: seen 2490000 words at 4034 wps, loss = 0.014
# [batch 2530]: seen 2531000 words at 4034 wps, loss = 0.014
# [batch 2569]: seen 2570000 words at 4032 wps, loss = 0.014
# [batch 2610]: seen 2611000 words at 4033 wps, loss = 0.014
# [batch 2651]: seen 2652000 words at 4033 wps, loss = 0.014
# [batch 2692]: seen 2693000 words at 4034 wps, loss = 0.013
# [batch 2733]: seen 2734000 words at 4034 wps, loss = 0.013
# [batch 2774]: seen 2775000 words at 4034 wps, loss = 0.013
# [batch 2815]: seen 2816000 words at 4035 wps, loss = 0.013
# [batch 2856]: seen 2857000 words at 4036 wps, loss = 0.013
# [batch 2896]: seen 2897000 words at 4034 wps, loss = 0.012
# [batch 2936]: seen 2937000 words at 4032 wps, loss = 0.012
# [batch 2977]: seen 2978000 words at 4033 wps, loss = 0.012
# [batch 3017]: seen 3018000 words at 4032 wps, loss = 0.012
# [batch 3058]: seen 3059000 words at 4032 wps, loss = 0.012
# [batch 3101]: seen 3102000 words at 4034 wps, loss = 0.012
# [batch 3142]: seen 3143000 words at 4033 wps, loss = 0.011
# [batch 3183]: seen 3184000 words at 4034 wps, loss = 0.011
# [batch 3226]: seen 3227000 words at 4036 wps, loss = 0.011
# [batch 3266]: seen 3267000 words at 4035 wps, loss = 0.011
# [batch 3307]: seen 3308000 words at 4035 wps, loss = 0.011
# [batch 3349]: seen 3350000 words at 4036 wps, loss = 0.011
# [batch 3389]: seen 3390000 words at 4035 wps, loss = 0.011
# [batch 3429]: seen 3430000 words at 4035 wps, loss = 0.011
# [batch 3470]: seen 3471000 words at 4035 wps, loss = 0.010
# [batch 3512]: seen 3513000 words at 4037 wps, loss = 0.010
# [batch 3552]: seen 3553000 words at 4036 wps, loss = 0.010
# [batch 3592]: seen 3593000 words at 4035 wps, loss = 0.010
# [batch 3635]: seen 3636000 words at 4037 wps, loss = 0.010
# [batch 3674]: seen 3675000 words at 4035 wps, loss = 0.010
# [batch 3716]: seen 3717000 words at 4036 wps, loss = 0.010
# [batch 3756]: seen 3757000 words at 4035 wps, loss = 0.010
# [batch 3798]: seen 3799000 words at 4036 wps, loss = 0.009
# [batch 3839]: seen 3840000 words at 4036 wps, loss = 0.009
# [batch 3880]: seen 3881000 words at 4036 wps, loss = 0.009
# [batch 3921]: seen 3922000 words at 4036 wps, loss = 0.009
# [batch 3963]: seen 3964000 words at 4037 wps, loss = 0.009
# [batch 4005]: seen 4006000 words at 4039 wps, loss = 0.009
# [batch 4046]: seen 4047000 words at 4039 wps, loss = 0.009
# [batch 4087]: seen 4088000 words at 4038 wps, loss = 0.009
# [batch 4128]: seen 4129000 words at 4038 wps, loss = 0.009
# [batch 4169]: seen 4170000 words at 4038 wps, loss = 0.009
# [batch 4211]: seen 4212000 words at 4039 wps, loss = 0.009
# [batch 4252]: seen 4253000 words at 4040 wps, loss = 0.008
# [batch 4292]: seen 4293000 words at 4039 wps, loss = 0.008
# [batch 4334]: seen 4335000 words at 4041 wps, loss = 0.008
# [batch 4375]: seen 4376000 words at 4041 wps, loss = 0.008
# [batch 4415]: seen 4416000 words at 4040 wps, loss = 0.008
# [batch 4456]: seen 4457000 words at 4040 wps, loss = 0.008
# [batch 4497]: seen 4498000 words at 4040 wps, loss = 0.008
# [batch 4537]: seen 4538000 words at 4039 wps, loss = 0.008
# [batch 4578]: seen 4579000 words at 4040 wps, loss = 0.008
# [batch 4620]: seen 4621000 words at 4040 wps, loss = 0.008
# [batch 4661]: seen 4662000 words at 4040 wps, loss = 0.008
# [batch 4702]: seen 4703000 words at 4041 wps, loss = 0.008
# [batch 4743]: seen 4744000 words at 4041 wps, loss = 0.008
# [batch 4783]: seen 4784000 words at 4040 wps, loss = 0.008
# [batch 4824]: seen 4825000 words at 4040 wps, loss = 0.007
# [batch 4867]: seen 4868000 words at 4042 wps, loss = 0.007
# [batch 4908]: seen 4909000 words at 4042 wps, loss = 0.007
# [batch 4950]: seen 4951000 words at 4043 wps, loss = 0.007
# [batch 4990]: seen 4991000 words at 4043 wps, loss = 0.007
# [batch 5033]: seen 5034000 words at 4044 wps, loss = 0.007
# [batch 5073]: seen 5074000 words at 4044 wps, loss = 0.007
# [batch 5115]: seen 5116000 words at 4044 wps, loss = 0.007
# [batch 5156]: seen 5157000 words at 4044 wps, loss = 0.007
# [batch 5197]: seen 5198000 words at 4044 wps, loss = 0.007
# [batch 5238]: seen 5239000 words at 4044 wps, loss = 0.007
# [batch 5279]: seen 5280000 words at 4044 wps, loss = 0.007
# [batch 5321]: seen 5322000 words at 4045 wps, loss = 0.007
# [batch 5361]: seen 5362000 words at 4044 wps, loss = 0.007
# [batch 5401]: seen 5402000 words at 4044 wps, loss = 0.007
# [batch 5443]: seen 5444000 words at 4044 wps, loss = 0.007
# [batch 5483]: seen 5484000 words at 4043 wps, loss = 0.007
# [batch 5525]: seen 5526000 words at 4044 wps, loss = 0.007
# [batch 5566]: seen 5567000 words at 4044 wps, loss = 0.006
# [batch 5608]: seen 5609000 words at 4045 wps, loss = 0.006
# [batch 5651]: seen 5652000 words at 4046 wps, loss = 0.006
# [batch 5693]: seen 5694000 words at 4047 wps, loss = 0.006
# [batch 5735]: seen 5736000 words at 4048 wps, loss = 0.006
# [batch 5777]: seen 5778000 words at 4048 wps, loss = 0.006
# [batch 5819]: seen 5820000 words at 4049 wps, loss = 0.006
# [batch 5862]: seen 5863000 words at 4050 wps, loss = 0.006
# [batch 5903]: seen 5904000 words at 4050 wps, loss = 0.006
# [batch 5944]: seen 5945000 words at 4050 wps, loss = 0.006
# [batch 5985]: seen 5986000 words at 4050 wps, loss = 0.006
# [batch 6025]: seen 6026000 words at 4049 wps, loss = 0.006
# [batch 6067]: seen 6068000 words at 4050 wps, loss = 0.006
# [batch 6110]: seen 6111000 words at 4051 wps, loss = 0.006
# [batch 6151]: seen 6152000 words at 4051 wps, loss = 0.006
# [batch 6192]: seen 6193000 words at 4051 wps, loss = 0.006
# [batch 6231]: seen 6232000 words at 4050 wps, loss = 0.006
# [batch 6272]: seen 6273000 words at 4050 wps, loss = 0.006
# [batch 6314]: seen 6315000 words at 4051 wps, loss = 0.006
# [batch 6354]: seen 6355000 words at 4051 wps, loss = 0.006
# [batch 6395]: seen 6396000 words at 4051 wps, loss = 0.006
# [batch 6438]: seen 6439000 words at 4052 wps, loss = 0.006
# [batch 6477]: seen 6478000 words at 4051 wps, loss = 0.006
# [batch 6516]: seen 6517000 words at 4050 wps, loss = 0.006
# [batch 6557]: seen 6558000 words at 4050 wps, loss = 0.006
# [batch 6598]: seen 6599000 words at 4050 wps, loss = 0.005
# [batch 6639]: seen 6640000 words at 4051 wps, loss = 0.005
# [batch 6680]: seen 6681000 words at 4050 wps, loss = 0.005
# [batch 6720]: seen 6721000 words at 4050 wps, loss = 0.005
# [batch 6761]: seen 6762000 words at 4050 wps, loss = 0.005
# [batch 6803]: seen 6804000 words at 4050 wps, loss = 0.005
# [batch 6844]: seen 6845000 words at 4050 wps, loss = 0.005
# [batch 6886]: seen 6887000 words at 4051 wps, loss = 0.005
# [batch 6926]: seen 6927000 words at 4050 wps, loss = 0.005
# [batch 6969]: seen 6970000 words at 4051 wps, loss = 0.005
# [batch 7011]: seen 7012000 words at 4052 wps, loss = 0.005
# [batch 7052]: seen 7053000 words at 4052 wps, loss = 0.005
# [batch 7093]: seen 7094000 words at 4052 wps, loss = 0.005
# [batch 7134]: seen 7135000 words at 4052 wps, loss = 0.005
# [batch 7175]: seen 7176000 words at 4052 wps, loss = 0.005
# [batch 7217]: seen 7218000 words at 4053 wps, loss = 0.005
# [batch 7260]: seen 7261000 words at 4054 wps, loss = 0.005
# [batch 7302]: seen 7303000 words at 4054 wps, loss = 0.005
# [batch 7343]: seen 7344000 words at 4054 wps, loss = 0.005
# [batch 7384]: seen 7385000 words at 4054 wps, loss = 0.005
# [batch 7425]: seen 7426000 words at 4054 wps, loss = 0.005
# [batch 7465]: seen 7466000 words at 4054 wps, loss = 0.005
# [batch 7506]: seen 7507000 words at 4054 wps, loss = 0.005
# [batch 7548]: seen 7549000 words at 4054 wps, loss = 0.005
# [batch 7589]: seen 7590000 words at 4054 wps, loss = 0.005
# [epoch 1] Completed in 0:31:13
# [epoch 2] Starting epoch 2
# [batch 42]: seen 43000 words at 4206 wps, loss = 0.000
# [batch 85]: seen 86000 words at 4213 wps, loss = 0.000
# [batch 127]: seen 128000 words at 4207 wps, loss = 0.000
# [batch 169]: seen 170000 words at 4188 wps, loss = 0.000
# [batch 208]: seen 209000 words at 4128 wps, loss = 0.000
# [batch 249]: seen 250000 words at 4120 wps, loss = 0.000
# [batch 291]: seen 292000 words at 4114 wps, loss = 0.000
# [batch 333]: seen 334000 words at 4121 wps, loss = 0.000
# [batch 374]: seen 375000 words at 4112 wps, loss = 0.000
# [batch 416]: seen 417000 words at 4116 wps, loss = 0.000
# [batch 459]: seen 460000 words at 4124 wps, loss = 0.000
# [batch 499]: seen 500000 words at 4112 wps, loss = 0.000
# [batch 540]: seen 541000 words at 4110 wps, loss = 0.000
# [batch 583]: seen 584000 words at 4120 wps, loss = 0.000
# [batch 625]: seen 626000 words at 4122 wps, loss = 0.000
# [batch 666]: seen 667000 words at 4119 wps, loss = 0.000
# [batch 708]: seen 709000 words at 4118 wps, loss = 0.000
# [batch 750]: seen 751000 words at 4122 wps, loss = 0.000
# [batch 791]: seen 792000 words at 4119 wps, loss = 0.000
# [batch 833]: seen 834000 words at 4119 wps, loss = 0.000
# [batch 873]: seen 874000 words at 4114 wps, loss = 0.000
# [batch 915]: seen 916000 words at 4117 wps, loss = 0.000
# [batch 957]: seen 958000 words at 4116 wps, loss = 0.000
# [batch 1001]: seen 1002000 words at 4124 wps, loss = 0.000
# [batch 1042]: seen 1043000 words at 4122 wps, loss = 0.000
# [batch 1082]: seen 1083000 words at 4117 wps, loss = 0.000
# [batch 1124]: seen 1125000 words at 4118 wps, loss = 0.000
# [batch 1165]: seen 1166000 words at 4115 wps, loss = 0.000
# [batch 1206]: seen 1207000 words at 4112 wps, loss = 0.000
# [batch 1246]: seen 1247000 words at 4106 wps, loss = 0.000
# [batch 1288]: seen 1289000 words at 4109 wps, loss = 0.000
# [batch 1330]: seen 1331000 words at 4110 wps, loss = 0.000
# [batch 1372]: seen 1373000 words at 4112 wps, loss = 0.000
# [batch 1414]: seen 1415000 words at 4113 wps, loss = 0.000
# [batch 1455]: seen 1456000 words at 4110 wps, loss = 0.000
# [batch 1498]: seen 1499000 words at 4113 wps, loss = 0.000
# [batch 1539]: seen 1540000 words at 4112 wps, loss = 0.000
# [batch 1580]: seen 1581000 words at 4111 wps, loss = 0.000
# [batch 1621]: seen 1622000 words at 4109 wps, loss = 0.000
# [batch 1661]: seen 1662000 words at 4106 wps, loss = 0.000
# [batch 1703]: seen 1704000 words at 4106 wps, loss = 0.000
# [batch 1744]: seen 1745000 words at 4105 wps, loss = 0.000
# [batch 1786]: seen 1787000 words at 4106 wps, loss = 0.000
# [batch 1827]: seen 1828000 words at 4104 wps, loss = 0.000
# [batch 1868]: seen 1869000 words at 4103 wps, loss = 0.000
# [batch 1908]: seen 1909000 words at 4101 wps, loss = 0.000
# [batch 1951]: seen 1952000 words at 4103 wps, loss = 0.000
# [batch 1991]: seen 1992000 words at 4100 wps, loss = 0.000
# [batch 2031]: seen 2032000 words at 4098 wps, loss = 0.000
# [batch 2073]: seen 2074000 words at 4099 wps, loss = 0.000
# [batch 2114]: seen 2115000 words at 4097 wps, loss = 0.000
# [batch 2155]: seen 2156000 words at 4096 wps, loss = 0.000
# [batch 2195]: seen 2196000 words at 4093 wps, loss = 0.000
# [batch 2237]: seen 2238000 words at 4094 wps, loss = 0.000
# [batch 2277]: seen 2278000 words at 4093 wps, loss = 0.000
# [batch 2317]: seen 2318000 words at 4090 wps, loss = 0.000
# [batch 2359]: seen 2360000 words at 4090 wps, loss = 0.000
# [batch 2401]: seen 2402000 words at 4091 wps, loss = 0.000
# [batch 2442]: seen 2443000 words at 4090 wps, loss = 0.000
# [batch 2484]: seen 2485000 words at 4091 wps, loss = 0.000
# [batch 2526]: seen 2527000 words at 4091 wps, loss = 0.000
# [batch 2568]: seen 2569000 words at 4092 wps, loss = 0.000
# [batch 2608]: seen 2609000 words at 4090 wps, loss = 0.000
# [batch 2651]: seen 2652000 words at 4092 wps, loss = 0.000
# [batch 2694]: seen 2695000 words at 4093 wps, loss = 0.000
# [batch 2735]: seen 2736000 words at 4093 wps, loss = 0.000
# [batch 2778]: seen 2779000 words at 4096 wps, loss = 0.000
# [batch 2819]: seen 2820000 words at 4095 wps, loss = 0.000
# [batch 2861]: seen 2862000 words at 4095 wps, loss = 0.000
# [batch 2902]: seen 2903000 words at 4095 wps, loss = 0.000
# [batch 2943]: seen 2944000 words at 4095 wps, loss = 0.000
# [batch 2985]: seen 2986000 words at 4095 wps, loss = 0.000
# [batch 3026]: seen 3027000 words at 4093 wps, loss = 0.000
# [batch 3069]: seen 3070000 words at 4095 wps, loss = 0.000
# [batch 3110]: seen 3111000 words at 4094 wps, loss = 0.000
# [batch 3152]: seen 3153000 words at 4095 wps, loss = 0.000
# [batch 3194]: seen 3195000 words at 4095 wps, loss = 0.000
# [batch 3234]: seen 3235000 words at 4094 wps, loss = 0.000
# [batch 3275]: seen 3276000 words at 4093 wps, loss = 0.000
# [batch 3316]: seen 3317000 words at 4093 wps, loss = 0.000
# [batch 3357]: seen 3358000 words at 4092 wps, loss = 0.000
# [batch 3399]: seen 3400000 words at 4093 wps, loss = 0.000
# [batch 3441]: seen 3442000 words at 4093 wps, loss = 0.000
# [batch 3480]: seen 3481000 words at 4091 wps, loss = 0.000
# [batch 3520]: seen 3521000 words at 4089 wps, loss = 0.000
# [batch 3560]: seen 3561000 words at 4087 wps, loss = 0.000
# [batch 3601]: seen 3602000 words at 4087 wps, loss = 0.000
# [batch 3643]: seen 3644000 words at 4087 wps, loss = 0.000
# [batch 3685]: seen 3686000 words at 4087 wps, loss = 0.000
# [batch 3725]: seen 3726000 words at 4086 wps, loss = 0.000
# [batch 3767]: seen 3768000 words at 4086 wps, loss = 0.000
# [batch 3807]: seen 3808000 words at 4085 wps, loss = 0.000
# [batch 3848]: seen 3849000 words at 4085 wps, loss = 0.000
# [batch 3890]: seen 3891000 words at 4086 wps, loss = 0.000
# [batch 3934]: seen 3935000 words at 4088 wps, loss = 0.000
# [batch 3976]: seen 3977000 words at 4089 wps, loss = 0.000
# [batch 4017]: seen 4018000 words at 4088 wps, loss = 0.000
# [batch 4058]: seen 4059000 words at 4088 wps, loss = 0.000
# [batch 4099]: seen 4100000 words at 4087 wps, loss = 0.000
# [batch 4140]: seen 4141000 words at 4087 wps, loss = 0.000
# [batch 4182]: seen 4183000 words at 4087 wps, loss = 0.000
# [batch 4222]: seen 4223000 words at 4086 wps, loss = 0.000
# [batch 4263]: seen 4264000 words at 4086 wps, loss = 0.000
# [batch 4305]: seen 4306000 words at 4087 wps, loss = 0.000
# [batch 4346]: seen 4347000 words at 4087 wps, loss = 0.000
# [batch 4387]: seen 4388000 words at 4086 wps, loss = 0.000
# [batch 4429]: seen 4430000 words at 4086 wps, loss = 0.000
# [batch 4469]: seen 4470000 words at 4085 wps, loss = 0.000
# [batch 4510]: seen 4511000 words at 4084 wps, loss = 0.000
# [batch 4551]: seen 4552000 words at 4084 wps, loss = 0.000
# [batch 4592]: seen 4593000 words at 4084 wps, loss = 0.000
# [batch 4632]: seen 4633000 words at 4082 wps, loss = 0.000
# [batch 4673]: seen 4674000 words at 4082 wps, loss = 0.000
# [batch 4712]: seen 4713000 words at 4081 wps, loss = 0.000
# [batch 4752]: seen 4753000 words at 4079 wps, loss = 0.000
# [batch 4793]: seen 4794000 words at 4079 wps, loss = 0.000
# [batch 4834]: seen 4835000 words at 4079 wps, loss = 0.000
# [batch 4876]: seen 4877000 words at 4079 wps, loss = 0.000
# [batch 4917]: seen 4918000 words at 4079 wps, loss = 0.000
# [batch 4959]: seen 4960000 words at 4079 wps, loss = 0.000
# [batch 5001]: seen 5002000 words at 4080 wps, loss = 0.000
# [batch 5043]: seen 5044000 words at 4080 wps, loss = 0.000
# [batch 5084]: seen 5085000 words at 4080 wps, loss = 0.000
# [batch 5124]: seen 5125000 words at 4080 wps, loss = 0.000
# [batch 5165]: seen 5166000 words at 4079 wps, loss = 0.000
# [batch 5206]: seen 5207000 words at 4079 wps, loss = 0.000
# [batch 5247]: seen 5248000 words at 4080 wps, loss = 0.000
# [batch 5288]: seen 5289000 words at 4079 wps, loss = 0.000
# [batch 5329]: seen 5330000 words at 4078 wps, loss = 0.000
# [batch 5370]: seen 5371000 words at 4078 wps, loss = 0.000
# [batch 5411]: seen 5412000 words at 4078 wps, loss = 0.000
# [batch 5451]: seen 5452000 words at 4077 wps, loss = 0.000
# [batch 5492]: seen 5493000 words at 4076 wps, loss = 0.000
# [batch 5533]: seen 5534000 words at 4076 wps, loss = 0.000
# [batch 5573]: seen 5574000 words at 4075 wps, loss = 0.000
# [batch 5615]: seen 5616000 words at 4076 wps, loss = 0.000
# [batch 5656]: seen 5657000 words at 4076 wps, loss = 0.000
# [batch 5697]: seen 5698000 words at 4076 wps, loss = 0.000
# [batch 5738]: seen 5739000 words at 4076 wps, loss = 0.000
# [batch 5779]: seen 5780000 words at 4075 wps, loss = 0.000
# [batch 5820]: seen 5821000 words at 4075 wps, loss = 0.000
# [batch 5861]: seen 5862000 words at 4075 wps, loss = 0.000
# [batch 5904]: seen 5905000 words at 4076 wps, loss = 0.000
# [batch 5944]: seen 5945000 words at 4075 wps, loss = 0.000
# [batch 5985]: seen 5986000 words at 4075 wps, loss = 0.000
# [batch 6026]: seen 6027000 words at 4074 wps, loss = 0.000
# [batch 6067]: seen 6068000 words at 4074 wps, loss = 0.000
# [batch 6108]: seen 6109000 words at 4074 wps, loss = 0.000
# [batch 6149]: seen 6150000 words at 4074 wps, loss = 0.000
# [batch 6189]: seen 6190000 words at 4073 wps, loss = 0.000
# [batch 6229]: seen 6230000 words at 4072 wps, loss = 0.000
# [batch 6271]: seen 6272000 words at 4073 wps, loss = 0.000
# [batch 6312]: seen 6313000 words at 4072 wps, loss = 0.000
# [batch 6353]: seen 6354000 words at 4072 wps, loss = 0.000
# [batch 6394]: seen 6395000 words at 4072 wps, loss = 0.000
# [batch 6435]: seen 6436000 words at 4072 wps, loss = 0.000
# [batch 6476]: seen 6477000 words at 4072 wps, loss = 0.000
# [batch 6518]: seen 6519000 words at 4072 wps, loss = 0.000
# [batch 6558]: seen 6559000 words at 4071 wps, loss = 0.000
# [batch 6598]: seen 6599000 words at 4071 wps, loss = 0.000
# [batch 6638]: seen 6639000 words at 4070 wps, loss = 0.000
# [batch 6679]: seen 6680000 words at 4070 wps, loss = 0.000
# [batch 6720]: seen 6721000 words at 4070 wps, loss = 0.000
# [batch 6760]: seen 6761000 words at 4070 wps, loss = 0.000
# [batch 6803]: seen 6804000 words at 4070 wps, loss = 0.000
# [batch 6844]: seen 6845000 words at 4070 wps, loss = 0.000
# [batch 6886]: seen 6887000 words at 4071 wps, loss = 0.000
# [batch 6929]: seen 6930000 words at 4072 wps, loss = 0.000
# [batch 6969]: seen 6970000 words at 4071 wps, loss = 0.000
# [batch 7009]: seen 7010000 words at 4070 wps, loss = 0.000
# [batch 7051]: seen 7052000 words at 4070 wps, loss = 0.000
# [batch 7091]: seen 7092000 words at 4069 wps, loss = 0.000
# [batch 7131]: seen 7132000 words at 4069 wps, loss = 0.000
# [batch 7170]: seen 7171000 words at 4068 wps, loss = 0.000
# [batch 7211]: seen 7212000 words at 4067 wps, loss = 0.000
# [batch 7251]: seen 7252000 words at 4066 wps, loss = 0.000
# [batch 7293]: seen 7294000 words at 4067 wps, loss = 0.000
# [batch 7335]: seen 7336000 words at 4067 wps, loss = 0.000
# [batch 7377]: seen 7378000 words at 4068 wps, loss = 0.000
# [batch 7419]: seen 7420000 words at 4068 wps, loss = 0.000
# [batch 7461]: seen 7462000 words at 4069 wps, loss = 0.000
# [batch 7503]: seen 7504000 words at 4070 wps, loss = 0.000
# [batch 7544]: seen 7545000 words at 4070 wps, loss = 0.000
# [batch 7586]: seen 7587000 words at 4070 wps, loss = 0.000
# [epoch 2] Completed in 0:31:05
# [epoch 3] Starting epoch 3
# [batch 40]: seen 41000 words at 4089 wps, loss = 0.000
# [batch 81]: seen 82000 words at 4079 wps, loss = 0.000
# [batch 122]: seen 123000 words at 4064 wps, loss = 0.000
# [batch 163]: seen 164000 words at 4066 wps, loss = 0.000
# [batch 203]: seen 204000 words at 4053 wps, loss = 0.000
# [batch 244]: seen 245000 words at 4055 wps, loss = 0.000
# [batch 285]: seen 286000 words at 4056 wps, loss = 0.000
# [batch 325]: seen 326000 words at 4048 wps, loss = 0.000
# [batch 365]: seen 366000 words at 4038 wps, loss = 0.000
# [batch 405]: seen 406000 words at 4033 wps, loss = 0.000
# [batch 446]: seen 447000 words at 4033 wps, loss = 0.000
# [batch 488]: seen 489000 words at 4046 wps, loss = 0.000
# [batch 529]: seen 530000 words at 4043 wps, loss = 0.000
# [batch 572]: seen 573000 words at 4055 wps, loss = 0.000
# [batch 613]: seen 614000 words at 4052 wps, loss = 0.000
# [batch 655]: seen 656000 words at 4059 wps, loss = 0.000
# [batch 696]: seen 697000 words at 4057 wps, loss = 0.000
# [batch 738]: seen 739000 words at 4063 wps, loss = 0.000
# [batch 777]: seen 778000 words at 4053 wps, loss = 0.000
# [batch 818]: seen 819000 words at 4054 wps, loss = 0.000
# [batch 859]: seen 860000 words at 4052 wps, loss = 0.000
# [batch 901]: seen 902000 words at 4057 wps, loss = 0.000
# [batch 942]: seen 943000 words at 4057 wps, loss = 0.000
# [batch 984]: seen 985000 words at 4060 wps, loss = 0.000
# [batch 1025]: seen 1026000 words at 4061 wps, loss = 0.000
# [batch 1066]: seen 1067000 words at 4061 wps, loss = 0.000
# [batch 1108]: seen 1109000 words at 4064 wps, loss = 0.000
# [batch 1149]: seen 1150000 words at 4064 wps, loss = 0.000
# [batch 1190]: seen 1191000 words at 4065 wps, loss = 0.000
# [batch 1232]: seen 1233000 words at 4067 wps, loss = 0.000
# [batch 1273]: seen 1274000 words at 4066 wps, loss = 0.000
# [batch 1315]: seen 1316000 words at 4068 wps, loss = 0.000
# [batch 1356]: seen 1357000 words at 4066 wps, loss = 0.000
# [batch 1398]: seen 1399000 words at 4069 wps, loss = 0.000
# [batch 1439]: seen 1440000 words at 4069 wps, loss = 0.000
# [batch 1480]: seen 1481000 words at 4069 wps, loss = 0.000
# [batch 1521]: seen 1522000 words at 4069 wps, loss = 0.000
# [batch 1562]: seen 1563000 words at 4069 wps, loss = 0.000
# [batch 1604]: seen 1605000 words at 4072 wps, loss = 0.000
# [batch 1645]: seen 1646000 words at 4071 wps, loss = 0.000
# [batch 1686]: seen 1687000 words at 4071 wps, loss = 0.000
# [batch 1729]: seen 1730000 words at 4075 wps, loss = 0.000
# [batch 1770]: seen 1771000 words at 4074 wps, loss = 0.000
# [batch 1812]: seen 1813000 words at 4076 wps, loss = 0.000
# [batch 1854]: seen 1855000 words at 4078 wps, loss = 0.000
# [batch 1896]: seen 1897000 words at 4080 wps, loss = 0.000
# [batch 1937]: seen 1938000 words at 4080 wps, loss = 0.000
# [batch 1978]: seen 1979000 words at 4078 wps, loss = 0.000
# [batch 2017]: seen 2018000 words at 4073 wps, loss = 0.000
# [batch 2059]: seen 2060000 words at 4074 wps, loss = 0.000
# [batch 2099]: seen 2100000 words at 4071 wps, loss = 0.000
# [batch 2141]: seen 2142000 words at 4073 wps, loss = 0.000
# [batch 2183]: seen 2184000 words at 4074 wps, loss = 0.000
# [batch 2225]: seen 2226000 words at 4075 wps, loss = 0.000
# [batch 2267]: seen 2268000 words at 4076 wps, loss = 0.000
# [batch 2311]: seen 2312000 words at 4082 wps, loss = 0.000
# [batch 2353]: seen 2354000 words at 4083 wps, loss = 0.000
# [batch 2395]: seen 2396000 words at 4084 wps, loss = 0.000
# [batch 2437]: seen 2438000 words at 4084 wps, loss = 0.000
# [batch 2478]: seen 2479000 words at 4085 wps, loss = 0.000
# [batch 2519]: seen 2520000 words at 4083 wps, loss = 0.000
# [batch 2562]: seen 2563000 words at 4086 wps, loss = 0.000
# [batch 2604]: seen 2605000 words at 4087 wps, loss = 0.000
# [batch 2645]: seen 2646000 words at 4087 wps, loss = 0.000
# [batch 2687]: seen 2688000 words at 4088 wps, loss = 0.000
# [batch 2731]: seen 2732000 words at 4092 wps, loss = 0.000
# [batch 2773]: seen 2774000 words at 4092 wps, loss = 0.000
# [batch 2815]: seen 2816000 words at 4092 wps, loss = 0.000
# [batch 2858]: seen 2859000 words at 4094 wps, loss = 0.000
# [batch 2899]: seen 2900000 words at 4094 wps, loss = 0.000
# [batch 2942]: seen 2943000 words at 4095 wps, loss = 0.000
# [batch 2984]: seen 2985000 words at 4096 wps, loss = 0.000
# [batch 3026]: seen 3027000 words at 4096 wps, loss = 0.000
# [batch 3066]: seen 3067000 words at 4094 wps, loss = 0.000
# [batch 3108]: seen 3109000 words at 4095 wps, loss = 0.000
# [batch 3150]: seen 3151000 words at 4096 wps, loss = 0.000
# [batch 3192]: seen 3193000 words at 4097 wps, loss = 0.000
# [batch 3233]: seen 3234000 words at 4096 wps, loss = 0.000
# [batch 3273]: seen 3274000 words at 4094 wps, loss = 0.000
# [batch 3315]: seen 3316000 words at 4094 wps, loss = 0.000
# [batch 3357]: seen 3358000 words at 4095 wps, loss = 0.000
# [batch 3398]: seen 3399000 words at 4094 wps, loss = 0.000
# [batch 3439]: seen 3440000 words at 4094 wps, loss = 0.000
# [batch 3482]: seen 3483000 words at 4095 wps, loss = 0.000
# [batch 3524]: seen 3525000 words at 4095 wps, loss = 0.000
# [batch 3565]: seen 3566000 words at 4095 wps, loss = 0.000
# [batch 3607]: seen 3608000 words at 4096 wps, loss = 0.000
# [batch 3649]: seen 3650000 words at 4096 wps, loss = 0.000
# [batch 3691]: seen 3692000 words at 4097 wps, loss = 0.000
# [batch 3735]: seen 3736000 words at 4099 wps, loss = 0.000
# [batch 3775]: seen 3776000 words at 4098 wps, loss = 0.000
# [batch 3817]: seen 3818000 words at 4099 wps, loss = 0.000
# [batch 3859]: seen 3860000 words at 4100 wps, loss = 0.000
# [batch 3899]: seen 3900000 words at 4098 wps, loss = 0.000
# [batch 3941]: seen 3942000 words at 4098 wps, loss = 0.000
# [batch 3983]: seen 3984000 words at 4099 wps, loss = 0.000
# [batch 4024]: seen 4025000 words at 4098 wps, loss = 0.000
# [batch 4067]: seen 4068000 words at 4099 wps, loss = 0.000
# [batch 4108]: seen 4109000 words at 4099 wps, loss = 0.000
# [batch 4149]: seen 4150000 words at 4098 wps, loss = 0.000
# [batch 4190]: seen 4191000 words at 4098 wps, loss = 0.000
# [batch 4231]: seen 4232000 words at 4098 wps, loss = 0.000
# [batch 4274]: seen 4275000 words at 4099 wps, loss = 0.000
# [batch 4316]: seen 4317000 words at 4099 wps, loss = 0.000
# [batch 4358]: seen 4359000 words at 4099 wps, loss = 0.000
# [batch 4399]: seen 4400000 words at 4099 wps, loss = 0.000
# [batch 4441]: seen 4442000 words at 4099 wps, loss = 0.000
# [batch 4481]: seen 4482000 words at 4098 wps, loss = 0.000
# [batch 4522]: seen 4523000 words at 4098 wps, loss = 0.000
# [batch 4563]: seen 4564000 words at 4097 wps, loss = 0.000
# [batch 4605]: seen 4606000 words at 4098 wps, loss = 0.000
# [batch 4645]: seen 4646000 words at 4096 wps, loss = 0.000
# [batch 4686]: seen 4687000 words at 4096 wps, loss = 0.000
# [batch 4726]: seen 4727000 words at 4095 wps, loss = 0.000
# [batch 4768]: seen 4769000 words at 4096 wps, loss = 0.000
# [batch 4810]: seen 4811000 words at 4096 wps, loss = 0.000
# [batch 4852]: seen 4853000 words at 4097 wps, loss = 0.000
# [batch 4892]: seen 4893000 words at 4096 wps, loss = 0.000
# [batch 4933]: seen 4934000 words at 4095 wps, loss = 0.000
# [batch 4976]: seen 4977000 words at 4096 wps, loss = 0.000
# [batch 5015]: seen 5016000 words at 4094 wps, loss = 0.000
# [batch 5056]: seen 5057000 words at 4094 wps, loss = 0.000
# [batch 5096]: seen 5097000 words at 4093 wps, loss = 0.000
# [batch 5138]: seen 5139000 words at 4094 wps, loss = 0.000
# [batch 5181]: seen 5182000 words at 4095 wps, loss = 0.000
# [batch 5223]: seen 5224000 words at 4096 wps, loss = 0.000
# [batch 5265]: seen 5266000 words at 4096 wps, loss = 0.000
# [batch 5308]: seen 5309000 words at 4097 wps, loss = 0.000
# [batch 5349]: seen 5350000 words at 4097 wps, loss = 0.000
# [batch 5391]: seen 5392000 words at 4098 wps, loss = 0.000
# [batch 5433]: seen 5434000 words at 4098 wps, loss = 0.000
# [batch 5475]: seen 5476000 words at 4098 wps, loss = 0.000
# [batch 5518]: seen 5519000 words at 4099 wps, loss = 0.000
# [batch 5559]: seen 5560000 words at 4099 wps, loss = 0.000
# [batch 5601]: seen 5602000 words at 4100 wps, loss = 0.000
# [batch 5642]: seen 5643000 words at 4099 wps, loss = 0.000
# [batch 5683]: seen 5684000 words at 4099 wps, loss = 0.000
# [batch 5722]: seen 5723000 words at 4098 wps, loss = 0.000
# [batch 5764]: seen 5765000 words at 4098 wps, loss = 0.000
# [batch 5806]: seen 5807000 words at 4098 wps, loss = 0.000
# [batch 5847]: seen 5848000 words at 4098 wps, loss = 0.000
# [batch 5888]: seen 5889000 words at 4098 wps, loss = 0.000
# [batch 5930]: seen 5931000 words at 4098 wps, loss = 0.000
# [batch 5972]: seen 5973000 words at 4099 wps, loss = 0.000
# [batch 6015]: seen 6016000 words at 4100 wps, loss = 0.000
# [batch 6058]: seen 6059000 words at 4101 wps, loss = 0.000
# [batch 6102]: seen 6103000 words at 4103 wps, loss = 0.000
# [batch 6144]: seen 6145000 words at 4103 wps, loss = 0.000
# [batch 6185]: seen 6186000 words at 4103 wps, loss = 0.000
# [batch 6226]: seen 6227000 words at 4102 wps, loss = 0.000
# [batch 6268]: seen 6269000 words at 4103 wps, loss = 0.000
# [batch 6310]: seen 6311000 words at 4103 wps, loss = 0.000
# [batch 6353]: seen 6354000 words at 4103 wps, loss = 0.000
# [batch 6396]: seen 6397000 words at 4104 wps, loss = 0.000
# [batch 6439]: seen 6440000 words at 4105 wps, loss = 0.000
# [batch 6481]: seen 6482000 words at 4106 wps, loss = 0.000
# [batch 6524]: seen 6525000 words at 4107 wps, loss = 0.000
# [batch 6566]: seen 6567000 words at 4107 wps, loss = 0.000
# [batch 6608]: seen 6609000 words at 4107 wps, loss = 0.000
# [batch 6650]: seen 6651000 words at 4107 wps, loss = 0.000
# [batch 6692]: seen 6693000 words at 4107 wps, loss = 0.000
# [batch 6735]: seen 6736000 words at 4108 wps, loss = 0.000
# [batch 6776]: seen 6777000 words at 4108 wps, loss = 0.000
# [batch 6817]: seen 6818000 words at 4108 wps, loss = 0.000
# [batch 6858]: seen 6859000 words at 4108 wps, loss = 0.000
# [batch 6901]: seen 6902000 words at 4108 wps, loss = 0.000
# [batch 6943]: seen 6944000 words at 4109 wps, loss = 0.000
# [batch 6984]: seen 6985000 words at 4108 wps, loss = 0.000
# [batch 7026]: seen 7027000 words at 4108 wps, loss = 0.000
# [batch 7070]: seen 7071000 words at 4110 wps, loss = 0.000
# [batch 7110]: seen 7111000 words at 4109 wps, loss = 0.000
# [batch 7151]: seen 7152000 words at 4108 wps, loss = 0.000
# [batch 7193]: seen 7194000 words at 4109 wps, loss = 0.000
# [batch 7236]: seen 7237000 words at 4110 wps, loss = 0.000
# [batch 7278]: seen 7279000 words at 4110 wps, loss = 0.000
# [batch 7321]: seen 7322000 words at 4111 wps, loss = 0.000
# [batch 7362]: seen 7363000 words at 4110 wps, loss = 0.000
# [batch 7404]: seen 7405000 words at 4111 wps, loss = 0.000
# [batch 7445]: seen 7446000 words at 4110 wps, loss = 0.000
# [batch 7486]: seen 7487000 words at 4109 wps, loss = 0.000
# [batch 7527]: seen 7528000 words at 4109 wps, loss = 0.000
# [batch 7570]: seen 7571000 words at 4110 wps, loss = 0.000
# [epoch 3] Completed in 0:30:47
# [epoch 4] Starting epoch 4
# [batch 40]: seen 41000 words at 4043 wps, loss = 0.000
# [batch 82]: seen 83000 words at 4096 wps, loss = 0.000
# [batch 124]: seen 125000 words at 4119 wps, loss = 0.000
# [batch 166]: seen 167000 words at 4120 wps, loss = 0.000
# [batch 207]: seen 208000 words at 4114 wps, loss = 0.000
# [batch 249]: seen 250000 words at 4124 wps, loss = 0.000
# [batch 291]: seen 292000 words at 4132 wps, loss = 0.000
# [batch 332]: seen 333000 words at 4122 wps, loss = 0.000
# [batch 372]: seen 373000 words at 4106 wps, loss = 0.000
# [batch 414]: seen 415000 words at 4110 wps, loss = 0.000
# [batch 455]: seen 456000 words at 4102 wps, loss = 0.000
# [batch 498]: seen 499000 words at 4109 wps, loss = 0.000
# [batch 540]: seen 541000 words at 4111 wps, loss = 0.000
# [batch 580]: seen 581000 words at 4103 wps, loss = 0.000
# [batch 619]: seen 620000 words at 4089 wps, loss = 0.000
# [batch 660]: seen 661000 words at 4089 wps, loss = 0.000
# [batch 702]: seen 703000 words at 4093 wps, loss = 0.000
# [batch 743]: seen 744000 words at 4092 wps, loss = 0.000
# [batch 785]: seen 786000 words at 4097 wps, loss = 0.000
# [batch 825]: seen 826000 words at 4089 wps, loss = 0.000
# [batch 867]: seen 868000 words at 4090 wps, loss = 0.000
# [batch 909]: seen 910000 words at 4092 wps, loss = 0.000
# [batch 950]: seen 951000 words at 4089 wps, loss = 0.000
# [batch 992]: seen 993000 words at 4092 wps, loss = 0.000
# [batch 1033]: seen 1034000 words at 4092 wps, loss = 0.000
# [batch 1074]: seen 1075000 words at 4091 wps, loss = 0.000
# [batch 1117]: seen 1118000 words at 4096 wps, loss = 0.000
# [batch 1159]: seen 1160000 words at 4098 wps, loss = 0.000
# [batch 1201]: seen 1202000 words at 4100 wps, loss = 0.000
# [batch 1242]: seen 1243000 words at 4100 wps, loss = 0.000
# [batch 1286]: seen 1287000 words at 4108 wps, loss = 0.000
# [batch 1327]: seen 1328000 words at 4106 wps, loss = 0.000
# [batch 1369]: seen 1370000 words at 4108 wps, loss = 0.000
# [batch 1411]: seen 1412000 words at 4108 wps, loss = 0.000
# [batch 1452]: seen 1453000 words at 4108 wps, loss = 0.000
# [batch 1493]: seen 1494000 words at 4106 wps, loss = 0.000
# [batch 1535]: seen 1536000 words at 4107 wps, loss = 0.000
# [batch 1577]: seen 1578000 words at 4108 wps, loss = 0.000
# [batch 1618]: seen 1619000 words at 4107 wps, loss = 0.000
# [batch 1659]: seen 1660000 words at 4104 wps, loss = 0.000
# [batch 1701]: seen 1702000 words at 4105 wps, loss = 0.000
# [batch 1741]: seen 1742000 words at 4101 wps, loss = 0.000
# [batch 1783]: seen 1784000 words at 4102 wps, loss = 0.000
# [batch 1825]: seen 1826000 words at 4104 wps, loss = 0.000
# [batch 1866]: seen 1867000 words at 4102 wps, loss = 0.000
# [batch 1909]: seen 1910000 words at 4107 wps, loss = 0.000
# [batch 1951]: seen 1952000 words at 4108 wps, loss = 0.000
# [batch 1991]: seen 1992000 words at 4105 wps, loss = 0.000
# [batch 2032]: seen 2033000 words at 4105 wps, loss = 0.000
# [batch 2073]: seen 2074000 words at 4104 wps, loss = 0.000
# [batch 2113]: seen 2114000 words at 4101 wps, loss = 0.000
# [batch 2155]: seen 2156000 words at 4102 wps, loss = 0.000
# [batch 2196]: seen 2197000 words at 4102 wps, loss = 0.000
# [batch 2238]: seen 2239000 words at 4103 wps, loss = 0.000
# [batch 2282]: seen 2283000 words at 4107 wps, loss = 0.000
# [batch 2324]: seen 2325000 words at 4108 wps, loss = 0.000
# [batch 2365]: seen 2366000 words at 4106 wps, loss = 0.000
# [batch 2407]: seen 2408000 words at 4107 wps, loss = 0.000
# [batch 2449]: seen 2450000 words at 4107 wps, loss = 0.000
# [batch 2491]: seen 2492000 words at 4108 wps, loss = 0.000
# [batch 2534]: seen 2535000 words at 4109 wps, loss = 0.000
# [batch 2577]: seen 2578000 words at 4111 wps, loss = 0.000
# [batch 2617]: seen 2618000 words at 4109 wps, loss = 0.000
# [batch 2659]: seen 2660000 words at 4110 wps, loss = 0.000
# [batch 2703]: seen 2704000 words at 4113 wps, loss = 0.000
# [batch 2744]: seen 2745000 words at 4112 wps, loss = 0.000
# [batch 2786]: seen 2787000 words at 4112 wps, loss = 0.000
# [batch 2828]: seen 2829000 words at 4113 wps, loss = 0.000
# [batch 2869]: seen 2870000 words at 4112 wps, loss = 0.000
# [batch 2912]: seen 2913000 words at 4113 wps, loss = 0.000
# [batch 2954]: seen 2955000 words at 4113 wps, loss = 0.000
# [batch 2996]: seen 2997000 words at 4115 wps, loss = 0.000
# [batch 3039]: seen 3040000 words at 4117 wps, loss = 0.000
# [batch 3079]: seen 3080000 words at 4114 wps, loss = 0.000
# [batch 3120]: seen 3121000 words at 4114 wps, loss = 0.000
# [batch 3162]: seen 3163000 words at 4114 wps, loss = 0.000
# [batch 3204]: seen 3205000 words at 4114 wps, loss = 0.000
# [batch 3247]: seen 3248000 words at 4117 wps, loss = 0.000
# [batch 3290]: seen 3291000 words at 4118 wps, loss = 0.000
# [batch 3331]: seen 3332000 words at 4117 wps, loss = 0.000
# [batch 3373]: seen 3374000 words at 4118 wps, loss = 0.000
# [batch 3415]: seen 3416000 words at 4118 wps, loss = 0.000
# [batch 3457]: seen 3458000 words at 4119 wps, loss = 0.000
# [batch 3500]: seen 3501000 words at 4121 wps, loss = 0.000
# [batch 3543]: seen 3544000 words at 4122 wps, loss = 0.000
# [batch 3585]: seen 3586000 words at 4123 wps, loss = 0.000
# [batch 3627]: seen 3628000 words at 4123 wps, loss = 0.000
# [batch 3670]: seen 3671000 words at 4124 wps, loss = 0.000
# [batch 3713]: seen 3714000 words at 4126 wps, loss = 0.000
# [batch 3754]: seen 3755000 words at 4125 wps, loss = 0.000
# [batch 3796]: seen 3797000 words at 4126 wps, loss = 0.000
# [batch 3836]: seen 3837000 words at 4124 wps, loss = 0.000
# [batch 3878]: seen 3879000 words at 4124 wps, loss = 0.000
# [batch 3919]: seen 3920000 words at 4124 wps, loss = 0.000
# [batch 3962]: seen 3963000 words at 4124 wps, loss = 0.000
# [batch 4005]: seen 4006000 words at 4125 wps, loss = 0.000
# [batch 4047]: seen 4048000 words at 4125 wps, loss = 0.000
# [batch 4090]: seen 4091000 words at 4126 wps, loss = 0.000
# [batch 4132]: seen 4133000 words at 4126 wps, loss = 0.000
# [batch 4175]: seen 4176000 words at 4128 wps, loss = 0.000
# [batch 4217]: seen 4218000 words at 4127 wps, loss = 0.000
# [batch 4260]: seen 4261000 words at 4129 wps, loss = 0.000
# [batch 4301]: seen 4302000 words at 4128 wps, loss = 0.000
# [batch 4343]: seen 4344000 words at 4128 wps, loss = 0.000
# [batch 4385]: seen 4386000 words at 4128 wps, loss = 0.000
# [batch 4426]: seen 4427000 words at 4127 wps, loss = 0.000
# [batch 4469]: seen 4470000 words at 4128 wps, loss = 0.000
# [batch 4512]: seen 4513000 words at 4129 wps, loss = 0.000
# [batch 4554]: seen 4555000 words at 4130 wps, loss = 0.000
# [batch 4595]: seen 4596000 words at 4129 wps, loss = 0.000
# [batch 4637]: seen 4638000 words at 4129 wps, loss = 0.000
# [batch 4679]: seen 4680000 words at 4129 wps, loss = 0.000
# [batch 4721]: seen 4722000 words at 4129 wps, loss = 0.000
# [batch 4763]: seen 4764000 words at 4130 wps, loss = 0.000
# [batch 4806]: seen 4807000 words at 4131 wps, loss = 0.000
# [batch 4849]: seen 4850000 words at 4132 wps, loss = 0.000
# [batch 4892]: seen 4893000 words at 4133 wps, loss = 0.000
# [batch 4935]: seen 4936000 words at 4134 wps, loss = 0.000
# [batch 4977]: seen 4978000 words at 4134 wps, loss = 0.000
# [batch 5020]: seen 5021000 words at 4135 wps, loss = 0.000
# [batch 5064]: seen 5065000 words at 4136 wps, loss = 0.000
# [batch 5106]: seen 5107000 words at 4136 wps, loss = 0.000
# [batch 5149]: seen 5150000 words at 4137 wps, loss = 0.000
# [batch 5190]: seen 5191000 words at 4137 wps, loss = 0.000
# [batch 5232]: seen 5233000 words at 4137 wps, loss = 0.000
# [batch 5274]: seen 5275000 words at 4137 wps, loss = 0.000
# [batch 5315]: seen 5316000 words at 4136 wps, loss = 0.000
# [batch 5356]: seen 5357000 words at 4135 wps, loss = 0.000
# [batch 5399]: seen 5400000 words at 4136 wps, loss = 0.000
# [batch 5442]: seen 5443000 words at 4137 wps, loss = 0.000
# [batch 5483]: seen 5484000 words at 4136 wps, loss = 0.000
# [batch 5524]: seen 5525000 words at 4136 wps, loss = 0.000
# [batch 5563]: seen 5564000 words at 4133 wps, loss = 0.000
# [batch 5605]: seen 5606000 words at 4133 wps, loss = 0.000
# [batch 5647]: seen 5648000 words at 4134 wps, loss = 0.000
# [batch 5692]: seen 5693000 words at 4136 wps, loss = 0.000
# [batch 5734]: seen 5735000 words at 4136 wps, loss = 0.000
# [batch 5776]: seen 5777000 words at 4136 wps, loss = 0.000
# [batch 5819]: seen 5820000 words at 4137 wps, loss = 0.000
# [batch 5861]: seen 5862000 words at 4137 wps, loss = 0.000
# [batch 5903]: seen 5904000 words at 4137 wps, loss = 0.000
# [batch 5945]: seen 5946000 words at 4136 wps, loss = 0.000
# [batch 5988]: seen 5989000 words at 4137 wps, loss = 0.000
# [batch 6029]: seen 6030000 words at 4137 wps, loss = 0.000
# [batch 6072]: seen 6073000 words at 4138 wps, loss = 0.000
# [batch 6116]: seen 6117000 words at 4139 wps, loss = 0.000
# [batch 6157]: seen 6158000 words at 4139 wps, loss = 0.000
# [batch 6198]: seen 6199000 words at 4138 wps, loss = 0.000
# [batch 6240]: seen 6241000 words at 4138 wps, loss = 0.000
# [batch 6283]: seen 6284000 words at 4139 wps, loss = 0.000
# [batch 6324]: seen 6325000 words at 4138 wps, loss = 0.000
# [batch 6366]: seen 6367000 words at 4138 wps, loss = 0.000
# [batch 6408]: seen 6409000 words at 4138 wps, loss = 0.000
# [batch 6450]: seen 6451000 words at 4138 wps, loss = 0.000
# [batch 6492]: seen 6493000 words at 4139 wps, loss = 0.000
# [batch 6534]: seen 6535000 words at 4139 wps, loss = 0.000
# [batch 6576]: seen 6577000 words at 4139 wps, loss = 0.000
# [batch 6618]: seen 6619000 words at 4139 wps, loss = 0.000
# [batch 6660]: seen 6661000 words at 4139 wps, loss = 0.000
# [batch 6702]: seen 6703000 words at 4139 wps, loss = 0.000
# [batch 6743]: seen 6744000 words at 4138 wps, loss = 0.000
# [batch 6784]: seen 6785000 words at 4138 wps, loss = 0.000
# [batch 6824]: seen 6825000 words at 4137 wps, loss = 0.000
# [batch 6866]: seen 6867000 words at 4137 wps, loss = 0.000
# [batch 6908]: seen 6909000 words at 4137 wps, loss = 0.000
# [batch 6951]: seen 6952000 words at 4138 wps, loss = 0.000
# [batch 6994]: seen 6995000 words at 4138 wps, loss = 0.000
# [batch 7035]: seen 7036000 words at 4138 wps, loss = 0.000
# [batch 7078]: seen 7079000 words at 4138 wps, loss = 0.000
# [batch 7119]: seen 7120000 words at 4138 wps, loss = 0.000
# [batch 7160]: seen 7161000 words at 4138 wps, loss = 0.000
# [batch 7202]: seen 7203000 words at 4138 wps, loss = 0.000
# [batch 7243]: seen 7244000 words at 4137 wps, loss = 0.000
# [batch 7286]: seen 7287000 words at 4138 wps, loss = 0.000
# [batch 7328]: seen 7329000 words at 4138 wps, loss = 0.000
# [batch 7371]: seen 7372000 words at 4139 wps, loss = 0.000
# [batch 7412]: seen 7413000 words at 4138 wps, loss = 0.000
# [batch 7454]: seen 7455000 words at 4138 wps, loss = 0.000
# [batch 7496]: seen 7497000 words at 4138 wps, loss = 0.000
# [batch 7538]: seen 7539000 words at 4138 wps, loss = 0.000
# [batch 7578]: seen 7579000 words at 4138 wps, loss = 0.000
# [epoch 4] Completed in 0:30:35
# [epoch 5] Starting epoch 5
# [batch 41]: seen 42000 words at 4160 wps, loss = 0.000
# [batch 83]: seen 84000 words at 4170 wps, loss = 0.000
# [batch 124]: seen 125000 words at 4146 wps, loss = 0.000
# [batch 168]: seen 169000 words at 4187 wps, loss = 0.000
# [batch 210]: seen 211000 words at 4181 wps, loss = 0.000
# [batch 251]: seen 252000 words at 4156 wps, loss = 0.000
# [batch 293]: seen 294000 words at 4161 wps, loss = 0.000
# [batch 335]: seen 336000 words at 4165 wps, loss = 0.000
# [batch 377]: seen 378000 words at 4159 wps, loss = 0.000
# [batch 419]: seen 420000 words at 4157 wps, loss = 0.000
# [batch 459]: seen 460000 words at 4141 wps, loss = 0.000
# [batch 500]: seen 501000 words at 4137 wps, loss = 0.000
# [batch 543]: seen 544000 words at 4145 wps, loss = 0.000
# [batch 586]: seen 587000 words at 4152 wps, loss = 0.000
# [batch 628]: seen 629000 words at 4151 wps, loss = 0.000
# [batch 670]: seen 671000 words at 4151 wps, loss = 0.000
# [batch 711]: seen 712000 words at 4147 wps, loss = 0.000
# [batch 753]: seen 754000 words at 4148 wps, loss = 0.000
# [batch 795]: seen 796000 words at 4149 wps, loss = 0.000
# [batch 837]: seen 838000 words at 4151 wps, loss = 0.000
# [batch 879]: seen 880000 words at 4152 wps, loss = 0.000
# [batch 922]: seen 923000 words at 4156 wps, loss = 0.000
# [batch 965]: seen 966000 words at 4160 wps, loss = 0.000
# [batch 1007]: seen 1008000 words at 4160 wps, loss = 0.000
# [batch 1050]: seen 1051000 words at 4163 wps, loss = 0.000
# [batch 1093]: seen 1094000 words at 4165 wps, loss = 0.000
# [batch 1136]: seen 1137000 words at 4167 wps, loss = 0.000
# [batch 1177]: seen 1178000 words at 4162 wps, loss = 0.000
# [batch 1218]: seen 1219000 words at 4157 wps, loss = 0.000
# [batch 1258]: seen 1259000 words at 4151 wps, loss = 0.000
# [batch 1300]: seen 1301000 words at 4152 wps, loss = 0.000
# [batch 1341]: seen 1342000 words at 4149 wps, loss = 0.000
# [batch 1384]: seen 1385000 words at 4153 wps, loss = 0.000
# [batch 1425]: seen 1426000 words at 4151 wps, loss = 0.000
# [batch 1466]: seen 1467000 words at 4149 wps, loss = 0.000
# [batch 1508]: seen 1509000 words at 4148 wps, loss = 0.000
# [batch 1550]: seen 1551000 words at 4148 wps, loss = 0.000
# [batch 1592]: seen 1593000 words at 4146 wps, loss = 0.000
# [batch 1633]: seen 1634000 words at 4145 wps, loss = 0.000
# [batch 1673]: seen 1674000 words at 4141 wps, loss = 0.000
# [batch 1713]: seen 1714000 words at 4137 wps, loss = 0.000
# [batch 1755]: seen 1756000 words at 4137 wps, loss = 0.000
# [batch 1797]: seen 1798000 words at 4136 wps, loss = 0.000
# [batch 1839]: seen 1840000 words at 4136 wps, loss = 0.000
# [batch 1880]: seen 1881000 words at 4133 wps, loss = 0.000
# [batch 1923]: seen 1924000 words at 4137 wps, loss = 0.000
# [batch 1964]: seen 1965000 words at 4135 wps, loss = 0.000
# [batch 2006]: seen 2007000 words at 4135 wps, loss = 0.000
# [batch 2050]: seen 2051000 words at 4139 wps, loss = 0.000
# [batch 2092]: seen 2093000 words at 4139 wps, loss = 0.000
# [batch 2135]: seen 2136000 words at 4141 wps, loss = 0.000
# [batch 2178]: seen 2179000 words at 4142 wps, loss = 0.000
# [batch 2220]: seen 2221000 words at 4143 wps, loss = 0.000
# [batch 2262]: seen 2263000 words at 4144 wps, loss = 0.000
# [batch 2303]: seen 2304000 words at 4141 wps, loss = 0.000
# [batch 2347]: seen 2348000 words at 4145 wps, loss = 0.000
# [batch 2389]: seen 2390000 words at 4145 wps, loss = 0.000
# [batch 2432]: seen 2433000 words at 4147 wps, loss = 0.000
# [batch 2476]: seen 2477000 words at 4149 wps, loss = 0.000
# [batch 2518]: seen 2519000 words at 4149 wps, loss = 0.000
# [batch 2560]: seen 2561000 words at 4149 wps, loss = 0.000
# [batch 2601]: seen 2602000 words at 4147 wps, loss = 0.000
# [batch 2643]: seen 2644000 words at 4147 wps, loss = 0.000
# [batch 2684]: seen 2685000 words at 4145 wps, loss = 0.000
# [batch 2727]: seen 2728000 words at 4147 wps, loss = 0.000
# [batch 2769]: seen 2770000 words at 4147 wps, loss = 0.000
# [batch 2812]: seen 2813000 words at 4148 wps, loss = 0.000
# [batch 2856]: seen 2857000 words at 4151 wps, loss = 0.000
# [batch 2899]: seen 2900000 words at 4152 wps, loss = 0.000
# [batch 2937]: seen 2938000 words at 4147 wps, loss = 0.000
# [batch 2978]: seen 2979000 words at 4146 wps, loss = 0.000
# [batch 3022]: seen 3023000 words at 4148 wps, loss = 0.000
# [batch 3064]: seen 3065000 words at 4148 wps, loss = 0.000
# [batch 3106]: seen 3107000 words at 4148 wps, loss = 0.000
# [batch 3147]: seen 3148000 words at 4147 wps, loss = 0.000
# [batch 3190]: seen 3191000 words at 4148 wps, loss = 0.000
# [batch 3232]: seen 3233000 words at 4148 wps, loss = 0.000
# [batch 3274]: seen 3275000 words at 4148 wps, loss = 0.000
# [batch 3316]: seen 3317000 words at 4148 wps, loss = 0.000
# [batch 3359]: seen 3360000 words at 4150 wps, loss = 0.000
# [batch 3402]: seen 3403000 words at 4151 wps, loss = 0.000
# [batch 3444]: seen 3445000 words at 4151 wps, loss = 0.000
# [batch 3486]: seen 3487000 words at 4152 wps, loss = 0.000
# [batch 3529]: seen 3530000 words at 4153 wps, loss = 0.000
# [batch 3570]: seen 3571000 words at 4152 wps, loss = 0.000
# [batch 3613]: seen 3614000 words at 4154 wps, loss = 0.000
# [batch 3656]: seen 3657000 words at 4155 wps, loss = 0.000
# [batch 3699]: seen 3700000 words at 4157 wps, loss = 0.000
# [batch 3742]: seen 3743000 words at 4157 wps, loss = 0.000
# [batch 3786]: seen 3787000 words at 4160 wps, loss = 0.000
# [batch 3829]: seen 3830000 words at 4160 wps, loss = 0.000
# [batch 3872]: seen 3873000 words at 4161 wps, loss = 0.000
# [batch 3915]: seen 3916000 words at 4163 wps, loss = 0.000
# [batch 3958]: seen 3959000 words at 4164 wps, loss = 0.000
# [batch 4001]: seen 4002000 words at 4165 wps, loss = 0.000
# [batch 4043]: seen 4044000 words at 4165 wps, loss = 0.000
# [batch 4086]: seen 4087000 words at 4166 wps, loss = 0.000
# [batch 4128]: seen 4129000 words at 4166 wps, loss = 0.000
# [batch 4170]: seen 4171000 words at 4165 wps, loss = 0.000
# [batch 4211]: seen 4212000 words at 4164 wps, loss = 0.000
# [batch 4254]: seen 4255000 words at 4165 wps, loss = 0.000
# [batch 4295]: seen 4296000 words at 4164 wps, loss = 0.000
# [batch 4338]: seen 4339000 words at 4165 wps, loss = 0.000
# [batch 4382]: seen 4383000 words at 4167 wps, loss = 0.000
# [batch 4426]: seen 4427000 words at 4168 wps, loss = 0.000
# [batch 4468]: seen 4469000 words at 4168 wps, loss = 0.000
# [batch 4510]: seen 4511000 words at 4167 wps, loss = 0.000
# [batch 4552]: seen 4553000 words at 4167 wps, loss = 0.000
# [batch 4596]: seen 4597000 words at 4169 wps, loss = 0.000
# [batch 4639]: seen 4640000 words at 4169 wps, loss = 0.000
# [batch 4681]: seen 4682000 words at 4169 wps, loss = 0.000
# [batch 4723]: seen 4724000 words at 4169 wps, loss = 0.000
# [batch 4764]: seen 4765000 words at 4167 wps, loss = 0.000
# [batch 4806]: seen 4807000 words at 4167 wps, loss = 0.000
# [batch 4850]: seen 4851000 words at 4169 wps, loss = 0.000
# [batch 4893]: seen 4894000 words at 4170 wps, loss = 0.000
# [batch 4936]: seen 4937000 words at 4170 wps, loss = 0.000
# [batch 4977]: seen 4978000 words at 4169 wps, loss = 0.000
# [batch 5019]: seen 5020000 words at 4169 wps, loss = 0.000
# [batch 5061]: seen 5062000 words at 4170 wps, loss = 0.000
# [batch 5104]: seen 5105000 words at 4170 wps, loss = 0.000
# [batch 5146]: seen 5147000 words at 4170 wps, loss = 0.000
# [batch 5187]: seen 5188000 words at 4169 wps, loss = 0.000
# [batch 5230]: seen 5231000 words at 4170 wps, loss = 0.000
# [batch 5272]: seen 5273000 words at 4169 wps, loss = 0.000
# [batch 5315]: seen 5316000 words at 4170 wps, loss = 0.000
# [batch 5358]: seen 5359000 words at 4171 wps, loss = 0.000
# [batch 5401]: seen 5402000 words at 4172 wps, loss = 0.000
# [batch 5443]: seen 5444000 words at 4171 wps, loss = 0.000
# [batch 5484]: seen 5485000 words at 4170 wps, loss = 0.000
# [batch 5526]: seen 5527000 words at 4170 wps, loss = 0.000
# [batch 5567]: seen 5568000 words at 4169 wps, loss = 0.000
# [batch 5608]: seen 5609000 words at 4168 wps, loss = 0.000
# [batch 5651]: seen 5652000 words at 4169 wps, loss = 0.000
# [batch 5695]: seen 5696000 words at 4170 wps, loss = 0.000
# [batch 5738]: seen 5739000 words at 4171 wps, loss = 0.000
# [batch 5782]: seen 5783000 words at 4172 wps, loss = 0.000
# [batch 5826]: seen 5827000 words at 4173 wps, loss = 0.000
# [batch 5867]: seen 5868000 words at 4172 wps, loss = 0.000
# [batch 5909]: seen 5910000 words at 4172 wps, loss = 0.000
# [batch 5952]: seen 5953000 words at 4173 wps, loss = 0.000
# [batch 5996]: seen 5997000 words at 4174 wps, loss = 0.000
# [batch 6038]: seen 6039000 words at 4174 wps, loss = 0.000
# [batch 6081]: seen 6082000 words at 4175 wps, loss = 0.000
# [batch 6123]: seen 6124000 words at 4175 wps, loss = 0.000
# [batch 6166]: seen 6167000 words at 4175 wps, loss = 0.000
# [batch 6207]: seen 6208000 words at 4174 wps, loss = 0.000
# [batch 6251]: seen 6252000 words at 4175 wps, loss = 0.000
# [batch 6292]: seen 6293000 words at 4175 wps, loss = 0.000
# [batch 6334]: seen 6335000 words at 4175 wps, loss = 0.000
# [batch 6376]: seen 6377000 words at 4175 wps, loss = 0.000
# [batch 6419]: seen 6420000 words at 4175 wps, loss = 0.000
# [batch 6461]: seen 6462000 words at 4174 wps, loss = 0.000
# [batch 6502]: seen 6503000 words at 4174 wps, loss = 0.000
# [batch 6546]: seen 6547000 words at 4174 wps, loss = 0.000
# [batch 6588]: seen 6589000 words at 4175 wps, loss = 0.000
# [batch 6631]: seen 6632000 words at 4175 wps, loss = 0.000
# [batch 6672]: seen 6673000 words at 4174 wps, loss = 0.000
# [batch 6710]: seen 6711000 words at 4172 wps, loss = 0.000
# [batch 6751]: seen 6752000 words at 4171 wps, loss = 0.000
# [batch 6794]: seen 6795000 words at 4172 wps, loss = 0.000
# [batch 6835]: seen 6836000 words at 4171 wps, loss = 0.000
# [batch 6878]: seen 6879000 words at 4171 wps, loss = 0.000
# [batch 6920]: seen 6921000 words at 4171 wps, loss = 0.000
# [batch 6963]: seen 6964000 words at 4172 wps, loss = 0.000
# [batch 7005]: seen 7006000 words at 4172 wps, loss = 0.000
# [batch 7047]: seen 7048000 words at 4172 wps, loss = 0.000
# [batch 7091]: seen 7092000 words at 4173 wps, loss = 0.000
# [batch 7134]: seen 7135000 words at 4173 wps, loss = 0.000
# [batch 7175]: seen 7176000 words at 4172 wps, loss = 0.000
# [batch 7217]: seen 7218000 words at 4172 wps, loss = 0.000
# [batch 7258]: seen 7259000 words at 4171 wps, loss = 0.000
# [batch 7299]: seen 7300000 words at 4171 wps, loss = 0.000
# [batch 7340]: seen 7341000 words at 4170 wps, loss = 0.000
# [batch 7382]: seen 7383000 words at 4170 wps, loss = 0.000
# [batch 7424]: seen 7425000 words at 4170 wps, loss = 0.000
# [batch 7466]: seen 7467000 words at 4169 wps, loss = 0.000
# [batch 7508]: seen 7509000 words at 4170 wps, loss = 0.000
# [batch 7551]: seen 7552000 words at 4170 wps, loss = 0.000
# [batch 7593]: seen 7594000 words at 4170 wps, loss = 0.000
# [epoch 5] Completed in 0:30:21
# [epoch 5] Train set: avg. loss: 0.000  (perplexity: 1.00)
# [epoch 5] Test set: avg. loss: 0.000  (perplexity: 1.00)

# %%
def score_seq(lm, session, seq, vocab):
    """Score a sequence of words. Returns total log-probability."""
    padded_ids = vocab.words_to_ids(utils.canonicalize_words(["<s>"] + seq + ["</s>"], 
                                                             wordset=vocab.word_to_id))
    w = np.reshape(padded_ids[:-1], [1,-1])
    y = np.reshape(padded_ids[1:],  [1,-1])
    h = session.run(lm.initial_h_, {lm.input_w_: w})
    feed_dict = {lm.input_w_:w,
                 lm.target_y_:y,
                 lm.initial_h_:h,
                 lm.dropout_keep_prob_: 1.0}
    # Return log(P(seq)) = -1*loss
    return -1*session.run(lm.loss_, feed_dict)

def load_and_score(inputs, sort=False):
    """Load the trained model and score the given words."""
    lm = rnnlm.RNNLM(**model_params)
    lm.BuildCoreGraph()
    
    with lm.graph.as_default():
        saver = tf.train.Saver()

    with tf.Session(graph=lm.graph) as session:  
        # Load the trained model
        saver.restore(session, trained_filename)

        if isinstance(inputs[0], str) or isinstance(inputs[0], unicode):
            inputs = [inputs]

        # Actually run scoring
        results = []
        for words in inputs:
            score = score_seq(lm, session, words, vocab)
            results.append((score, words))

        # Sort if requested
        if sort: results = sorted(results, reverse=True)

        # Print results
        for score, words in results:
            print "\"%s\" : %.02f" % (" ".join(words), score)

# %%
sents = ["i shall be miserable if i have not an excellent library",
         "to be fond of dancing was a certain step towards falling in love",
         "don't let the door hit you on your way out",
         "he was totally into it",
         "to be or not to be",
         "come on y'all, don't be like that!",
         "get outta here",
        "the market dropped significantly today",
        "i do not fear computers, i fear the lack of them"]
load_and_score([s.split() for s in sents])
# Out:
# INFO:tensorflow:Restoring parameters from tf_saved/rnnlm_trained
# "i shall be miserable if i have not an excellent library" : -2.53
# "to be fond of dancing was a certain step towards falling in love" : -2.17
# "don't let the door hit you on your way out" : -2.76
# "he was totally into it" : -5.01
# "to be or not to be" : -4.31
# "come on y'all, don't be like that!" : -3.78
# "get outta here" : -11.36
# "the market dropped significantly today" : -5.01
# "i do not fear computers, i fear the lack of them" : -2.53
